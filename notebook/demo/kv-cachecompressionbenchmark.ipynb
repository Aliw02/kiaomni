# %% [markdown]
# # KiaOmni vs SnapKV (kvpress) vs Vanilla — Live Head-to-Head
#
# Public, reproducible comparison of three configurations of the **same model**:
#
# | Variant | Source |
# |---|---|
# | **Vanilla** | Full KV cache, no eviction (upper bound) |
# | **KiaOmni-Gaussian** | [`kiaomni`](https://github.com/Aliw02/kiaomni) — training-free, budget-exact eviction |
# | **SnapKV** | [`kvpress.SnapKVPress`](https://github.com/NVIDIA/kvpress) — NVIDIA's reference implementation of arXiv:2404.14469 |
#
# **Model:** Qwen2.5-7B-Instruct, 4-bit NF4 · **Context:** ~4K tokens · **Backend:** SDPA · **Decoding:** greedy
#
# **Tasks:** single-needle retrieval · multi-needle retrieval · reasoning (variable tracking) · summarization (key-fact coverage)
#
# **Budgets:** 98, 128, 256, 512 retained tokens. Budget matching is **exact**: for each prompt, kvpress's
# `compression_ratio` is computed per-sample so that `int(prompt_len * (1 - ratio)) == budget`, i.e. SnapKV and
# KiaOmni keep *exactly* the same number of KV positions. SnapKV runs with the kvpress reference defaults
# (`window_size=64`, `kernel_size=5`).
#
# **How to run on Kaggle:** Settings → Accelerator = GPU (T4 / P100) · Internet = ON · Run All.
#
# Set `VERBOSE = True` in the config cell to print every answer at every budget plus generation-PPL.
# With `VERBOSE = False` only budgets 128 and 512 are printed (all budgets are still *measured* and appear
# in the final tables and CSV).

# %%
# --- Installation (Kaggle: Internet must be ON) -------------------------------
# Order matters:
#   1) kvpress + runtime deps
#   2) force transformers into the window compatible with BOTH libraries
#      (kvpress needs >=4.56,<5.3 ; kiaomni needs >=4.50,<5.0  ->  pin <5.0)
#   3) kiaomni with --no-deps so pip does not touch the preinstalled CUDA torch
# %pip install -q kvpress bitsandbytes scipy
# %pip install -q -U "transformers>=4.56,<5.0" "accelerate<2"
# %pip install -q --no-deps git+https://github.com/Aliw02/kiaomni.git

import torch, transformers
import kvpress, kiaomni, bitsandbytes
v = transformers.__version__
assert v >= "4.56" and v < "5.0", f"transformers {v} outside the 4.56-5.0 compatibility window"
print(f"torch {torch.__version__} | transformers {v} | kiaomni {kiaomni.__version__}")
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "NONE (CPU run will be very slow)")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.3/94.3 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 31.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 91.8 MB/s eta 0:00:00:00:010:01
#   Building wheel for fire (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 97.5 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.2/389.2 kB 27.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 36.5 MB/s eta 0:00:00
# Note: you may need to restart the kernel to use updated packages.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for kiaomni (pyproject.toml) ... done
# Note: you may need to restart the kernel to use updated packages.
# 2026-06-13 09:07:29.267704: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1781341649.495892      58 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1781341649.557646      58 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1781341650.140101      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781341650.140137      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781341650.140141      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781341650.140143      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# torch 2.10.0+cu128 | transformers 4.57.6 | kiaomni 0.3.0
# GPU: Tesla T4

# %%
# --- Configuration -------------------------------------------------------------
VERBOSE = True            # True: print every budget + generation-PPL. False: print budgets {128, 512} only.

MODEL_NAME      = "Qwen/Qwen2.5-7B-Instruct"
CONTEXT_TOKENS  = 4000     # target prompt length in tokens (Kaggle-friendly 4K)
BUDGETS         = [98, 128, 256, 512, 1024, 2048, 3400]
PRINT_BUDGETS   = {128, 512}   # used when VERBOSE is False

N_SINGLE   = 10            # single-needle questions
N_MULTI    = 10            # multi-needle questions (3 needles each)
N_REASON   = 10            # variable-tracking questions
N_SUMMARY  = 3             # summarization documents

MAX_NEW = {"single": 24, "multi": 96, "reason": 24, "summary": 220}
SEED = 42

# SnapKV reference defaults from kvpress (do NOT change: this is the published baseline)
SNAPKV_WINDOW  = 64
SNAPKV_KERNEL  = 5

# %%
# --- Load model once (4-bit NF4, SDPA) ------------------------------------------
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig

bnb = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.float16,
)

tok = AutoTokenizer.from_pretrained(MODEL_NAME)
if tok.pad_token is None:
    tok.pad_token = tok.eos_token

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    quantization_config=bnb,
    device_map="auto",
    attn_implementation="sdpa",   # T4/P100 have no FlashAttention-2; SDPA is supported by both libraries
    torch_dtype=torch.float16,
)
model.eval()

if torch.cuda.is_available():
    print(f"Model loaded. VRAM after load: {torch.cuda.memory_allocated()/1e9:.2f} GB")
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.56G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.95G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# Model loaded. VRAM after load: 1.93 GB

# %%
# --- Engine: the three run modes, exact budget matching, metrics ----------------
import time, math, gc, re, logging
import torch
from kvpress import SnapKVPress
from kiaomni import apply_kiaomni, remove_kiaomni

# kiaomni logs an SDPA advisory on every apply_kiaomni call; with ~260 applies it would flood the log.
# SDPA is verified working (hook-based saliency observes q/k projections before the fused kernel).
logging.getLogger("kiaomni").setLevel(logging.ERROR)

def ratio_for_budget(prompt_len: int, budget: int) -> float:
    """kvpress keeps n_kept = int(prompt_len * (1 - ratio)).
    The +0.5 offset makes int() floor to exactly `budget`."""
    r = 1.0 - (budget + 0.5) / prompt_len
    assert 0.0 <= r < 1.0, f"prompt_len={prompt_len} too short for budget={budget}"
    return r

def build_inputs(context: str, question: str):
    messages = [{"role": "user", "content": f"{context}\n\n{question}"}]
    ids = tok.apply_chat_template(messages, add_generation_prompt=True, return_tensors="pt")
    return ids, torch.ones_like(ids)

def count_tokens(text: str) -> int:
    return len(tok(text, add_special_tokens=False).input_ids)

@torch.no_grad()
def _generate(input_ids, attention_mask, max_new):
    dev = next(model.parameters()).device
    input_ids, attention_mask = input_ids.to(dev), attention_mask.to(dev)
    cuda = torch.cuda.is_available()
    if cuda:
        torch.cuda.synchronize(); torch.cuda.reset_peak_memory_stats()
    t0 = time.perf_counter()
    out = model.generate(
        input_ids=input_ids, attention_mask=attention_mask,
        max_new_tokens=max_new, do_sample=False,
        output_scores=True, return_dict_in_generate=True,
        pad_token_id=tok.pad_token_id,
    )
    if cuda:
        torch.cuda.synchronize()
    dt = time.perf_counter() - t0

    n_new   = len(out.scores)
    new_ids = out.sequences[0, -n_new:]                    # robust even if the wrapper alters the prompt part
    logps   = [torch.log_softmax(s[0].float(), -1)[new_ids[i]].item()
               for i, s in enumerate(out.scores)]
    ppl  = math.exp(-sum(logps) / len(logps)) if logps else float("nan")
    vram = torch.cuda.max_memory_allocated() / 1e9 if cuda else 0.0
    text = tok.decode(new_ids, skip_special_tokens=True).strip()
    return {"text": text, "ppl": ppl, "tps": n_new / dt, "vram": vram, "secs": dt, "n_new": n_new}

def run_vanilla(ids, mask, max_new):
    return _generate(ids, mask, max_new)

def run_kiaomni(ids, mask, budget, max_new):
    apply_kiaomni(model, policy="kiaomni_gaussian", budget=budget)   # library defaults: n_sink=16, recency=32
    try:
        return _generate(ids, mask, max_new)
    finally:
        remove_kiaomni(model)

def run_snapkv(ids, mask, budget, max_new):
    press = SnapKVPress(
        compression_ratio=ratio_for_budget(ids.shape[1], budget),
        window_size=SNAPKV_WINDOW, kernel_size=SNAPKV_KERNEL,
    )
    with press(model):
        return _generate(ids, mask, max_new)

def cleanup():
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

# --- printing helpers -----------------------------------------------------------
def fmt_metrics(res):
    s = f"{res['tps']:5.1f} tok/s | {res['vram']:.2f} GB"
    if VERBOSE:
        s += f" | GenPPL {res['ppl']:7.2f}"
    return s

def print_run(label, res, mark, clip=170):
    txt = " ".join(res["text"].split())
    if len(txt) > clip:
        txt = txt[: clip - 3] + "..."
    print(f"  {label:<24} {mark}  [{fmt_metrics(res)}]")
    print(f"  {'':<24}    -> {txt}")

def should_print(budget):
    return VERBOSE or budget in PRINT_BUDGETS

# %%
# --- Task generators (deterministic, seeded) ------------------------------------
import random

_SUBJ = ["The committee", "A regional survey", "The maintenance crew", "An early prototype",
         "The northern facility", "A visiting delegation", "The archive department", "Local observers",
         "The pilot program", "A follow-up study", "The logistics team", "An internal memo",
         "The harbor authority", "A quarterly audit", "The training division", "Field engineers"]
_VERB = ["reported", "confirmed", "documented", "reviewed", "scheduled", "postponed",
         "evaluated", "inspected", "catalogued", "summarized", "approved", "recorded"]
_OBJ  = ["minor adjustments to the ventilation schedule", "a gradual rise in afternoon foot traffic",
         "the relocation of two storage containers", "routine calibration of the measurement rigs",
         "an updated rotation plan for night shifts", "the replacement of worn signage near gate three",
         "consistent humidity readings across all halls", "a backlog of paperwork from the previous quarter",
         "slower than expected delivery of spare parts", "general satisfaction with the new canteen layout",
         "uneven wear on the loading dock surface", "stable energy consumption throughout the week"]

def _sentence(rng):
    return f"{rng.choice(_SUBJ)} {rng.choice(_VERB)} {rng.choice(_OBJ)}."

def build_haystack(rng, reserved_tokens):
    """Return a list of filler sentences totalling ~CONTEXT_TOKENS - reserved_tokens."""
    target = CONTEXT_TOKENS - reserved_tokens
    sents, step = [], 40
    while count_tokens(" ".join(sents)) < target:
        sents.extend(_sentence(rng) for _ in range(step))
    while count_tokens(" ".join(sents)) > target and sents:
        sents.pop()
    return sents

def _insert(sents, items):
    """items: list of (depth in 0..1, sentence). Returns joined context."""
    out = list(sents)
    for depth, s in sorted(items, key=lambda x: x[0], reverse=True):
        out.insert(int(depth * len(out)), s)
    return " ".join(out)

DEPTHS = [0.10, 0.30, 0.50, 0.70, 0.90]

def make_single(i):
    rng  = random.Random(SEED + 100 + i)
    code = rng.randint(100000, 999999)
    depth = DEPTHS[i % len(DEPTHS)]
    needle = f"Note for the security desk: the secret access code for vault {chr(65 + i % 26)} is {code}."
    q = "What is the secret access code mentioned in the document? Answer with the number only."
    ctx = _insert(build_haystack(rng, reserved_tokens=80), [(depth, needle)])
    gold = str(code)
    def check(ans):
        ok = re.search(rf"\b{gold}\b", ans) is not None
        return ok, ("found" if ok else "missing")
    return {"ctx": ctx, "q": q, "gold": gold, "check": check,
            "info": f"code={gold} @ depth {int(depth*100)}%"}

def make_multi(i):
    rng = random.Random(SEED + 200 + i)
    code   = rng.randint(100000, 999999)
    locker = rng.randint(100, 999)
    name   = rng.choice(["FALCON", "GRANITE", "MERIDIAN", "COBALT", "JUNIPER",
                         "VERTEX", "HARBOR", "QUARTZ", "SABLE", "ORCHID"])
    needles = [
        (0.20, f"For the record, the access code is {code}."),
        (0.50, f"Equipment update: the spare keys were moved to locker {locker}."),
        (0.80, f"Personnel note: the liaison operates under the codename {name}."),
    ]
    q = ("The document hides three secret values: an access code, a locker number, "
         "and a codename. List all three values.")
    ctx  = _insert(build_haystack(rng, reserved_tokens=140), needles)
    gold = [str(code), str(locker), name]
    def check(ans):
        up = ans.upper()
        found = sum(1 for g in gold if re.search(rf"\b{g}\b", up))
        return found == 3, f"{found}/3 needles"
    return {"ctx": ctx, "q": q, "gold": ", ".join(gold), "check": check,
            "info": "3 needles @ 20/50/80%"}

def make_reason(i):
    rng  = random.Random(SEED + 300 + i)
    val  = rng.randint(10000, 99999)
    dval = rng.randint(10000, 99999)
    while dval == val:
        dval = rng.randint(10000, 99999)
    A, B, C, D = (f"V{rng.randint(10,99)}{c}" for c in "ABCD")
    X, Y       = (f"V{rng.randint(10,99)}{c}" for c in "XY")
    chain = [
        (0.15, f"Assignment log: variable {A} was set to {val}."),
        (0.40, f"Assignment log: variable {B} was set to the value of {A}."),
        (0.60, f"Assignment log: variable {C} was set to the value of {B}."),
        (0.85, f"Assignment log: variable {D} was set to the value of {C}."),
        (0.25, f"Assignment log: variable {X} was set to {dval}."),               # distractor chain
        (0.70, f"Assignment log: variable {Y} was set to the value of {X}."),
    ]
    q = (f"Track the variable assignments in the document. "
         f"What is the final value of variable {D}? Answer with the number only.")
    ctx  = _insert(build_haystack(rng, reserved_tokens=180), chain)
    gold = str(val)
    def check(ans):
        hit  = re.search(rf"\b{gold}\b", ans) is not None
        dist = re.search(rf"\b{dval}\b", ans) is not None
        ok = hit and not dist
        return ok, ("correct" if ok else ("distractor value" if dist else "missing"))
    return {"ctx": ctx, "q": q, "gold": gold, "check": check,
            "info": f"4-hop chain, answer {gold}, distractor {dval}"}

def make_summary(i):
    rng = random.Random(SEED + 400 + i)
    company = rng.choice(["Altavera Systems", "Norwind Logistics", "Helios Materials"])
    facts = {
        "revenue":  f"{rng.randint(11, 48)}.{rng.randint(1,9)} million",
        "headcount": str(rng.randint(180, 950)),
        "churn":    f"{rng.randint(2, 9)}.{rng.randint(0,9)}%",
        "nps":      str(rng.randint(31, 78)),
        "runway":   f"{rng.randint(9, 30)} months",
        "city":     rng.choice(["Riga", "Porto", "Tallinn", "Valencia"]),
        "defects":  f"{rng.randint(1, 6)}.{rng.randint(0,9)} per thousand units",
        "launch":   rng.choice(["March", "June", "September", "November"]),
    }
    sections = [
        f"QUARTERLY REVIEW - {company}.",
        f"Finance. Total revenue for the quarter reached {facts['revenue']} dollars, and the cash runway now stands at {facts['runway']}.",
        f"People. Headcount closed at {facts['headcount']} employees after the {facts['city']} office expansion.",
        f"Customers. Monthly churn was {facts['churn']} while the net promoter score reached {facts['nps']}.",
        f"Operations. The defect rate improved to {facts['defects']}, and the next product launch is scheduled for {facts['launch']}.",
    ]
    rng2  = random.Random(SEED + 500 + i)
    sents = build_haystack(rng2, reserved_tokens=count_tokens(" ".join(sections)) + 80)
    block = len(sents) // len(sections)
    woven = []
    for k, sec in enumerate(sections):
        woven.append(sec)
        woven.extend(sents[k * block:(k + 1) * block])
    ctx = " ".join(woven)
    q = ("Summarize this quarterly review in 5-8 sentences. "
         "Include every concrete figure: revenue, headcount, churn, NPS, runway, "
         "expansion city, defect rate, and launch month.")
    keys = list(facts.values())
    def check(ans):
        up = ans.upper()
        hits = sum(1 for v in keys if v.upper() in up)
        return hits / len(keys), f"{hits}/{len(keys)} key facts"
    return {"ctx": ctx, "q": q, "gold": "; ".join(f"{k}={v}" for k, v in facts.items()),
            "check": check, "info": f"{company}, 8 planted facts"}

# %%
# --- Run everything --------------------------------------------------------------
results = []   # one row per generation

TASKS = [
    ("single",  make_single,  N_SINGLE),
    ("multi",   make_multi,   N_MULTI),
    ("reason",  make_reason,  N_REASON),
    ("summary", make_summary, N_SUMMARY),
]
total_runs = sum(n for _, _, n in TASKS) * (1 + 2 * len(BUDGETS))
print(f"Total generations: {total_runs} "
      f"({sum(n for *_, n in TASKS)} samples x (1 vanilla + 2 methods x {len(BUDGETS)} budgets))\n")

def record(task, sid, method, budget, res, score, detail):
    results.append({"task": task, "sample": sid, "method": method,
                    "budget": budget if budget is not None else 0,
                    "score": float(score), "detail": detail,
                    "tps": res["tps"], "vram": res["vram"], "ppl": res["ppl"],
                    "text": res["text"]})

t_start = time.perf_counter()
done = 0

for task, maker, n in TASKS:
    print("=" * 100)
    print(f"TASK: {task.upper()}  ({n} samples)")
    print("=" * 100)
    for sid in range(n):
        s = maker(sid)
        ids, mask = build_inputs(s["ctx"], s["q"])
        plen = ids.shape[1]
        print(f"\n[{task} #{sid + 1}]  prompt = {plen} tokens  |  {s['info']}")
        print(f"  GOLD: {s['gold']}")
        print("-" * 100)

        is_summary = task == "summary"

        # ---- vanilla (once per sample) ----
        res = run_vanilla(ids, mask, MAX_NEW[task]); done += 1
        sc, det = s["check"](res["text"])
        mark = f"{sc * 100:5.1f}% facts" if is_summary else ("PASS" if sc else "FAIL")
        if is_summary:
            print(f"  Vanilla (full cache)      {mark} ({det})  [{fmt_metrics(res)}]")
            print("    " + res["text"].replace("\n", "\n    "))
        else:
            print_run("Vanilla (full cache)", res, f"{mark} ({det})")
        record(task, sid, "Vanilla", None, res, sc, det)

        # ---- both methods at every budget ----
        for budget in BUDGETS:
            for mname, runner in (("KiaOmni-Gaussian", run_kiaomni), ("SnapKV", run_snapkv)):
                res = runner(ids, mask, budget, MAX_NEW[task]); done += 1
                sc, det = s["check"](res["text"])
                mark = f"{sc * 100:5.1f}% facts" if is_summary else ("PASS" if sc else "FAIL")
                if should_print(budget):
                    label = f"{mname}  B={budget}"
                    if is_summary:
                        print(f"  {label:<24} {mark} ({det})  [{fmt_metrics(res)}]")
                        print("    " + res["text"].replace("\n", "\n    "))
                    else:
                        print_run(label, res, f"{mark} ({det})")
                record(task, sid, mname, budget, res, sc, det)
        cleanup()

        if done and sid == 0 and task == "single":
            per = (time.perf_counter() - t_start) / done
            print(f"\n  [timing] {per:.1f}s per generation -> "
                  f"estimated total ~{per * total_runs / 60:.0f} min")

print(f"\nDone. {done} generations in {(time.perf_counter() - t_start) / 60:.1f} min.")
# Out:
# Total generations: 495 (33 samples x (1 vanilla + 2 methods x 7 budgets))
#
# ====================================================================================================
# TASK: SINGLE  (10 samples)
# ====================================================================================================
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# [single #1]  prompt = 3979 tokens  |  code=710888 @ depth 10%
#   GOLD: 710888
# ----------------------------------------------------------------------------------------------------
#   Vanilla (full cache)     PASS (found)  [  0.9 tok/s | 6.42 GB | GenPPL    1.00]
#                               -> 710888
#   KiaOmni-Gaussian  B=98   PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 710888
#   SnapKV  B=98             FAIL (missing)  [  1.0 tok/s | 6.37 GB | GenPPL    1.52]
#                               -> 719253
#   KiaOmni-Gaussian  B=128  PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 710888
#   SnapKV  B=128            FAIL (missing)  [  1.0 tok/s | 6.37 GB | GenPPL    1.35]
#                               -> 710952
#   KiaOmni-Gaussian  B=256  PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 710888
#   SnapKV  B=256            PASS (found)  [  1.0 tok/s | 6.37 GB | GenPPL    1.00]
#                               -> 710888
#   KiaOmni-Gaussian  B=512  PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 710888
#   SnapKV  B=512            PASS (found)  [  1.0 tok/s | 6.37 GB | GenPPL    1.00]
#                               -> 710888
#   KiaOmni-Gaussian  B=1024 PASS (found)  [  1.0 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 710888
#   SnapKV  B=1024           PASS (found)  [  1.0 tok/s | 6.38 GB | GenPPL    1.00]
#                               -> 710888
#   KiaOmni-Gaussian  B=2048 PASS (found)  [  0.9 tok/s | 3.23 GB | GenPPL    1.00]
#                               -> 710888
#   SnapKV  B=2048           PASS (found)  [  0.9 tok/s | 6.39 GB | GenPPL    1.00]
#                               -> 710888
#   KiaOmni-Gaussian  B=3400 PASS (found)  [  0.6 tok/s | 5.26 GB | GenPPL    1.00]
#                               -> 710888
#   SnapKV  B=3400           PASS (found)  [  0.9 tok/s | 6.41 GB | GenPPL    1.00]
#                               -> 710888
#
#   [timing] 7.3s per generation -> estimated total ~60 min
#
# [single #2]  prompt = 3982 tokens  |  code=292863 @ depth 30%
#   GOLD: 292863
# ----------------------------------------------------------------------------------------------------
#   Vanilla (full cache)     PASS (found)  [  0.9 tok/s | 6.42 GB | GenPPL    1.00]
#                               -> 292863
#   KiaOmni-Gaussian  B=98   PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 292863
#   SnapKV  B=98             FAIL (missing)  [  0.9 tok/s | 6.37 GB | GenPPL    1.49]
#                               -> 298754
#   KiaOmni-Gaussian  B=128  PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 292863
#   SnapKV  B=128            FAIL (missing)  [  0.9 tok/s | 6.38 GB | GenPPL    1.46]
#                               -> 298735
#   KiaOmni-Gaussian  B=256  PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 292863
#   SnapKV  B=256            PASS (found)  [  0.9 tok/s | 6.38 GB | GenPPL    1.02]
#                               -> 292863
#   KiaOmni-Gaussian  B=512  PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 292863
#   SnapKV  B=512            FAIL (missing)  [  0.9 tok/s | 6.38 GB | GenPPL    1.19]
#                               -> 292847
#   KiaOmni-Gaussian  B=1024 PASS (found)  [  1.0 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 292863
#   SnapKV  B=1024           PASS (found)  [  0.9 tok/s | 6.39 GB | GenPPL    1.00]
#                               -> 292863
#   KiaOmni-Gaussian  B=2048 PASS (found)  [  0.8 tok/s | 3.23 GB | GenPPL    1.00]
#                               -> 292863
#   SnapKV  B=2048           PASS (found)  [  0.9 tok/s | 6.40 GB | GenPPL    1.00]
#                               -> 292863
#   KiaOmni-Gaussian  B=3400 PASS (found)  [  0.6 tok/s | 5.26 GB | GenPPL    1.00]
#                               -> 292863
#   SnapKV  B=3400           PASS (found)  [  0.9 tok/s | 6.42 GB | GenPPL    1.00]
#                               -> 292863
#
# [single #3]  prompt = 3980 tokens  |  code=570042 @ depth 50%
#   GOLD: 570042
# ----------------------------------------------------------------------------------------------------
#   Vanilla (full cache)     PASS (found)  [  0.9 tok/s | 6.42 GB | GenPPL    1.00]
#                               -> 570042
#   KiaOmni-Gaussian  B=98   PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 570042
#   SnapKV  B=98             FAIL (missing)  [  0.9 tok/s | 6.37 GB | GenPPL    1.74]
#                               -> 562893
#   KiaOmni-Gaussian  B=128  PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 570042
#   SnapKV  B=128            FAIL (missing)  [  0.9 tok/s | 6.37 GB | GenPPL    1.09]
#                               -> 570428
#   KiaOmni-Gaussian  B=256  PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 570042
#   SnapKV  B=256            FAIL (missing)  [  0.8 tok/s | 6.37 GB | GenPPL    1.04]
#                               -> 57042
#   KiaOmni-Gaussian  B=512  PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 570042
#   SnapKV  B=512            PASS (found)  [  0.9 tok/s | 6.37 GB | GenPPL    1.01]
#                               -> 570042
#   KiaOmni-Gaussian  B=1024 PASS (found)  [  1.0 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 570042
#   SnapKV  B=1024           PASS (found)  [  0.9 tok/s | 6.38 GB | GenPPL    1.06]
#                               -> 570042
#   KiaOmni-Gaussian  B=2048 PASS (found)  [  0.8 tok/s | 3.23 GB | GenPPL    1.00]
#                               -> 570042
#   SnapKV  B=2048           PASS (found)  [  0.9 tok/s | 6.39 GB | GenPPL    1.00]
#                               -> 570042
#   KiaOmni-Gaussian  B=3400 PASS (found)  [  0.6 tok/s | 5.26 GB | GenPPL    1.00]
#                               -> 570042
#   SnapKV  B=3400           PASS (found)  [  0.9 tok/s | 6.41 GB | GenPPL    1.00]
#                               -> 570042
#
# [single #4]  prompt = 3981 tokens  |  code=894263 @ depth 70%
#   GOLD: 894263
# ----------------------------------------------------------------------------------------------------
#   Vanilla (full cache)     PASS (found)  [  0.9 tok/s | 6.42 GB | GenPPL    1.00]
#                               -> 894263
#   KiaOmni-Gaussian  B=98   PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 894263
#   SnapKV  B=98             FAIL (missing)  [  0.9 tok/s | 6.37 GB | GenPPL    1.44]
#                               -> 892537
#   KiaOmni-Gaussian  B=128  PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 894263
#   SnapKV  B=128            FAIL (missing)  [  0.9 tok/s | 6.37 GB | GenPPL    1.14]
#                               -> 894567
#   KiaOmni-Gaussian  B=256  PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 894263
#   SnapKV  B=256            PASS (found)  [  0.9 tok/s | 6.37 GB | GenPPL    1.00]
#                               -> 894263
#   KiaOmni-Gaussian  B=512  PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 894263
#   SnapKV  B=512            PASS (found)  [  0.9 tok/s | 6.38 GB | GenPPL    1.00]
#                               -> 894263
#   KiaOmni-Gaussian  B=1024 PASS (found)  [  1.0 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 894263
#   SnapKV  B=1024           PASS (found)  [  0.9 tok/s | 6.38 GB | GenPPL    1.00]
#                               -> 894263
#   KiaOmni-Gaussian  B=2048 PASS (found)  [  0.8 tok/s | 3.23 GB | GenPPL    1.00]
#                               -> 894263
#   SnapKV  B=2048           PASS (found)  [  0.9 tok/s | 6.40 GB | GenPPL    1.00]
#                               -> 894263
#   KiaOmni-Gaussian  B=3400 PASS (found)  [  0.6 tok/s | 5.26 GB | GenPPL    1.00]
#                               -> 894263
#   SnapKV  B=3400           PASS (found)  [  0.9 tok/s | 6.41 GB | GenPPL    1.00]
#                               -> 894263
#
# [single #5]  prompt = 3982 tokens  |  code=239812 @ depth 90%
#   GOLD: 239812
# ----------------------------------------------------------------------------------------------------
#   Vanilla (full cache)     PASS (found)  [  0.9 tok/s | 6.42 GB | GenPPL    1.00]
#                               -> 239812
#   KiaOmni-Gaussian  B=98   PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 239812
#   SnapKV  B=98             FAIL (missing)  [  0.9 tok/s | 6.37 GB | GenPPL    1.15]
#                               -> 234567
#   KiaOmni-Gaussian  B=128  PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 239812
#   SnapKV  B=128            FAIL (missing)  [  0.9 tok/s | 6.38 GB | GenPPL    1.11]
#                               -> 239157
#   KiaOmni-Gaussian  B=256  PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 239812
#   SnapKV  B=256            FAIL (missing)  [  0.9 tok/s | 6.38 GB | GenPPL    1.26]
#                               -> 239856
#   KiaOmni-Gaussian  B=512  PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 239812
#   SnapKV  B=512            PASS (found)  [  0.9 tok/s | 6.38 GB | GenPPL    1.00]
#                               -> 239812
#   KiaOmni-Gaussian  B=1024 PASS (found)  [  1.0 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 239812
#   SnapKV  B=1024           FAIL (missing)  [  0.8 tok/s | 6.39 GB | GenPPL    1.09]
#                               -> 23912
#   KiaOmni-Gaussian  B=2048 PASS (found)  [  0.9 tok/s | 3.23 GB | GenPPL    1.00]
#                               -> 239812
#   SnapKV  B=2048           PASS (found)  [  0.9 tok/s | 6.40 GB | GenPPL    1.00]
#                               -> 239812
#   KiaOmni-Gaussian  B=3400 PASS (found)  [  0.6 tok/s | 5.26 GB | GenPPL    1.00]
#                               -> 239812
#   SnapKV  B=3400           PASS (found)  [  0.9 tok/s | 6.42 GB | GenPPL    1.00]
#                               -> 239812
#
# [single #6]  prompt = 3983 tokens  |  code=734640 @ depth 10%
#   GOLD: 734640
# ----------------------------------------------------------------------------------------------------
#   Vanilla (full cache)     PASS (found)  [  0.9 tok/s | 6.42 GB | GenPPL    1.00]
#                               -> 734640
#   KiaOmni-Gaussian  B=98   PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 734640
#   SnapKV  B=98             FAIL (missing)  [  0.9 tok/s | 6.38 GB | GenPPL    1.53]
#                               -> 735928
#   KiaOmni-Gaussian  B=128  PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 734640
#   SnapKV  B=128            FAIL (missing)  [  0.7 tok/s | 6.38 GB | GenPPL    1.05]
#                               -> 7340
#   KiaOmni-Gaussian  B=256  PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 734640
#   SnapKV  B=256            FAIL (missing)  [  0.9 tok/s | 6.38 GB | GenPPL    1.60]
#                               -> 734295
#   KiaOmni-Gaussian  B=512  PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 734640
#   SnapKV  B=512            PASS (found)  [  0.9 tok/s | 6.38 GB | GenPPL    1.08]
#                               -> 734640
#   KiaOmni-Gaussian  B=1024 PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 734640
#   SnapKV  B=1024           PASS (found)  [  0.9 tok/s | 6.39 GB | GenPPL    1.00]
#                               -> 734640
#   KiaOmni-Gaussian  B=2048 PASS (found)  [  0.9 tok/s | 3.23 GB | GenPPL    1.00]
#                               -> 734640
#   SnapKV  B=2048           PASS (found)  [  0.9 tok/s | 6.40 GB | GenPPL    1.00]
#                               -> 734640
#   KiaOmni-Gaussian  B=3400 PASS (found)  [  0.6 tok/s | 5.26 GB | GenPPL    1.00]
#                               -> 734640
#   SnapKV  B=3400           PASS (found)  [  0.9 tok/s | 6.42 GB | GenPPL    1.00]
#                               -> 734640
#
# [single #7]  prompt = 3983 tokens  |  code=523102 @ depth 30%
#   GOLD: 523102
# ----------------------------------------------------------------------------------------------------
#   Vanilla (full cache)     PASS (found)  [  0.9 tok/s | 6.42 GB | GenPPL    1.00]
#                               -> 523102
#   KiaOmni-Gaussian  B=98   PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 523102
#   SnapKV  B=98             FAIL (missing)  [  0.8 tok/s | 6.38 GB | GenPPL    1.60]
#                               -> 52018
#   KiaOmni-Gaussian  B=128  PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 523102
#   SnapKV  B=128            FAIL (missing)  [  0.9 tok/s | 6.38 GB | GenPPL    1.34]
#                               -> 523402
#   KiaOmni-Gaussian  B=256  PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 523102
#   SnapKV  B=256            PASS (found)  [  0.9 tok/s | 6.38 GB | GenPPL    1.00]
#                               -> 523102
#   KiaOmni-Gaussian  B=512  PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 523102
#   SnapKV  B=512            PASS (found)  [  0.9 tok/s | 6.38 GB | GenPPL    1.00]
#                               -> 523102
#   KiaOmni-Gaussian  B=1024 PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 523102
#   SnapKV  B=1024           PASS (found)  [  0.9 tok/s | 6.39 GB | GenPPL    1.01]
#                               -> 523102
#   KiaOmni-Gaussian  B=2048 PASS (found)  [  0.9 tok/s | 3.23 GB | GenPPL    1.00]
#                               -> 523102
#   SnapKV  B=2048           PASS (found)  [  0.9 tok/s | 6.40 GB | GenPPL    1.02]
#                               -> 523102
#   KiaOmni-Gaussian  B=3400 PASS (found)  [  0.6 tok/s | 5.26 GB | GenPPL    1.00]
#                               -> 523102
#   SnapKV  B=3400           PASS (found)  [  0.9 tok/s | 6.42 GB | GenPPL    1.00]
#                               -> 523102
#
# [single #8]  prompt = 3978 tokens  |  code=174561 @ depth 50%
#   GOLD: 174561
# ----------------------------------------------------------------------------------------------------
#   Vanilla (full cache)     PASS (found)  [  0.9 tok/s | 6.41 GB | GenPPL    1.00]
#                               -> 174561
#   KiaOmni-Gaussian  B=98   PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 174561
#   SnapKV  B=98             FAIL (missing)  [  0.9 tok/s | 6.37 GB | GenPPL    1.60]
#                               -> 174592
#   KiaOmni-Gaussian  B=128  PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 174561
#   SnapKV  B=128            FAIL (missing)  [  0.9 tok/s | 6.37 GB | GenPPL    1.31]
#                               -> 174692
#   KiaOmni-Gaussian  B=256  PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 174561
#   SnapKV  B=256            FAIL (missing)  [  0.9 tok/s | 6.37 GB | GenPPL    1.12]
#                               -> 174592
#   KiaOmni-Gaussian  B=512  PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 174561
#   SnapKV  B=512            PASS (found)  [  0.9 tok/s | 6.37 GB | GenPPL    1.00]
#                               -> 174561
#   KiaOmni-Gaussian  B=1024 PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 174561
#   SnapKV  B=1024           PASS (found)  [  0.9 tok/s | 6.38 GB | GenPPL    1.00]
#                               -> 174561
#   KiaOmni-Gaussian  B=2048 PASS (found)  [  0.9 tok/s | 3.23 GB | GenPPL    1.00]
#                               -> 174561
#   SnapKV  B=2048           PASS (found)  [  0.9 tok/s | 6.39 GB | GenPPL    1.00]
#                               -> 174561
#   KiaOmni-Gaussian  B=3400 PASS (found)  [  0.6 tok/s | 5.26 GB | GenPPL    1.00]
#                               -> 174561
#   SnapKV  B=3400           PASS (found)  [  0.9 tok/s | 6.41 GB | GenPPL    1.00]
#                               -> 174561
#
# [single #9]  prompt = 3983 tokens  |  code=963824 @ depth 70%
#   GOLD: 963824
# ----------------------------------------------------------------------------------------------------
#   Vanilla (full cache)     PASS (found)  [  0.9 tok/s | 6.42 GB | GenPPL    1.00]
#                               -> 963824
#   KiaOmni-Gaussian  B=98   PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 963824
#   SnapKV  B=98             FAIL (missing)  [  0.3 tok/s | 6.38 GB | GenPPL    1.57]
#                               -> 9
#   KiaOmni-Gaussian  B=128  PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 963824
#   SnapKV  B=128            FAIL (missing)  [  0.9 tok/s | 6.38 GB | GenPPL    1.15]
#                               -> 963248
#   KiaOmni-Gaussian  B=256  PASS (found)  [  1.2 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 963824
#   SnapKV  B=256            FAIL (missing)  [  0.8 tok/s | 6.38 GB | GenPPL    1.18]
#                               -> 96324
#   KiaOmni-Gaussian  B=512  PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 963824
#   SnapKV  B=512            PASS (found)  [  0.9 tok/s | 6.38 GB | GenPPL    1.00]
#                               -> 963824
#   KiaOmni-Gaussian  B=1024 PASS (found)  [  1.1 tok/s | 3.15 GB | GenPPL    1.00]
#                               -> 963824
#   SnapKV  B=1024           PASS (found)  [  0.9 tok/s | 6.39 GB | GenPPL    1.00]
#                               -> 963824
#   KiaOmni-Gaussian  B=2048 PASS (found)  [  0.9 tok/s | 3.23 GB | GenPPL    1.00]
#                               -> 963824
#   SnapKV  B=2048           PASS (found)  [  0.9 tok/s | 6.40 GB | GenPPL    1.00]
#                               -> 963824
#   KiaOmni-Gaussian  B=3400 PASS (found)  [  0.6 tok/s | 5.26 GB | GenPPL    1.00]
#                               -> 963824
#   SnapKV  B=3400           PASS (found)  [  0.9 tok/s | 6.42 GB | GenPPL    1.00]
#                               -> 963824
#
# [single #10]  prompt = 3986 tokens  |  code=840896 @ depth 90%
#   GOLD: 840896
# ----------------------------------------------------------------------------------------------------
#   Vanilla (full cache)     PASS (found)  [  0.9 tok/s | 6.43 GB | GenPPL    1.00]
#                               -> 840896
#   KiaOmni-Gaussian  B=98   PASS (found)  [  1.2 tok/s | 3.16 GB | GenPPL    1.00]
#                               -> 840896
#   SnapKV  B=98             FAIL (missing)  [  0.9 tok/s | 6.38 GB | GenPPL    1.20]
#                               -> 846925
#   KiaOmni-Gaussian  B=128  PASS (found)  [  1.2 tok/s | 3.16 GB | GenPPL    1.00]
#                               -> 840896
#   SnapKV  B=128            FAIL (missing)  [  0.8 tok/s | 6.38 GB | GenPPL    1.09]
#                               -> 84096
#   KiaOmni-Gaussian  B=256  PASS (found)  [  1.2 tok/s | 3.16 GB | GenPPL    1.00]
#                               -> 840896
#   SnapKV  B=256            FAIL (missing)  [  0.8 tok/s | 6.39 GB | GenPPL    1.00]
#                               -> 84096
#   KiaOmni-Gaussian  B=512  PASS (found)  [  1.1 tok/s | 3.16 GB | GenPPL    1.00]
#                               -> 840896
#   SnapKV  B=512            FAIL (missing)  [  0.8 tok/s | 6.39 GB | GenPPL    1.10]
#                               -> 84096
#   KiaOmni-Gaussian  B=1024 PASS (found)  [  1.1 tok/s | 3.16 GB | GenPPL    1.00]
#                               -> 840896
#   SnapKV  B=1024           PASS (found)  [  0.9 tok/s | 6.40 GB | GenPPL    1.00]
#                               -> 840896
#   KiaOmni-Gaussian  B=2048 PASS (found)  [  0.9 tok/s | 3.23 GB | GenPPL    1.00]
#                               -> 840896
#   SnapKV  B=2048           PASS (found)  [  0.9 tok/s | 6.41 GB | GenPPL    1.00]
#                               -> 840896
#   KiaOmni-Gaussian  B=3400 PASS (found)  [  0.6 tok/s | 5.26 GB | GenPPL    1.00]
#                               -> 840896
#   SnapKV  B=3400           PASS (found)  [  0.9 tok/s | 6.42 GB | GenPPL    1.00]
#                               -> 840896
# ====================================================================================================
# TASK: MULTI  (10 samples)
# ====================================================================================================
#
# [multi #1]  prompt = 3948 tokens  |  3 needles @ 20/50/80%
#   GOLD: 451646, 128, QUARTZ
# ----------------------------------------------------------------------------------------------------
#   Vanilla (full cache)     PASS (3/3 needles)  [  3.7 tok/s | 6.35 GB | GenPPL    1.05]
#                               -> Based on the information provided in the document: 1. **Access Code**: 451646 2. **Locker Number**: 128 3. **Codename**: QUARTZ
#   KiaOmni-Gaussian  B=98   FAIL (2/3 needles)  [  7.3 tok/s | 3.14 GB | GenPPL    1.17]
#                               -> Based on the information provided in the document: 1. The access code is 451646. 2. The locker number is not explicitly mentioned, but it can be inferred from "the lia...
#   SnapKV  B=98             FAIL (1/3 needles)  [  6.2 tok/s | 6.30 GB | GenPPL    1.26]
#                               -> Based on the information provided in your request: 1. **Access Code**: 456789 (This was not explicitly stated but derived from the context given in the document.) 2. *...
#   KiaOmni-Gaussian  B=128  FAIL (2/3 needles)  [  7.2 tok/s | 3.14 GB | GenPPL    1.22]
#                               -> Based on the information provided in the document, the three secret values are: 1. Access code: 451646 2. Locker number: Not explicitly mentioned in the given text. 3....
#   SnapKV  B=128            FAIL (1/3 needles)  [  6.1 tok/s | 6.30 GB | GenPPL    1.33]
#                               -> Based on the information provided in your message, the three secret values hidden in the document are: 1. **Access Code**: 456 (This was not explicitly stated as the a...
#   KiaOmni-Gaussian  B=256  PASS (3/3 needles)  [  5.0 tok/s | 3.14 GB | GenPPL    1.06]
#                               -> Based on the information provided in the document, the three secret values are: 1. Access code: 451646 2. Locker number: 128 3. Codename: QUARTZ
#   SnapKV  B=256            FAIL (2/3 needles)  [  6.1 tok/s | 6.30 GB | GenPPL    1.12]
#                               -> Based on the information provided in the document: 1. **Access Code**: 456456 2. **Locker Number**: 128 3. **Codename**: QUARTZ These values are derived from the expli...
#   KiaOmni-Gaussian  B=512  PASS (3/3 needles)  [  5.1 tok/s | 3.14 GB | GenPPL    1.05]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 451646 2. **Locker Number**: 128 3. **Codename**: QUARTZ
#   SnapKV  B=512            FAIL (2/3 needles)  [  6.1 tok/s | 6.31 GB | GenPPL    1.11]
#                               -> Based on the information provided in the document: 1. **Access Code**: 45646 2. **Locker Number**: 128 3. **Codename**: QUARTZ These values are derived from the explic...
#   KiaOmni-Gaussian  B=1024 PASS (3/3 needles)  [  4.9 tok/s | 3.14 GB | GenPPL    1.05]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 451646 2. **Locker Number**: 128 3. **Codename**: QUARTZ
#   SnapKV  B=1024           PASS (3/3 needles)  [  4.0 tok/s | 6.31 GB | GenPPL    1.05]
#                               -> Based on the information provided in the document: 1. **Access Code**: 451646 2. **Locker Number**: 128 3. **Codename**: QUARTZ
#   KiaOmni-Gaussian  B=2048 PASS (3/3 needles)  [  4.3 tok/s | 3.23 GB | GenPPL    1.06]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 451646 2. **Locker Number**: 128 3. **Codename**: QUARTZ
#   SnapKV  B=2048           PASS (3/3 needles)  [  3.8 tok/s | 6.33 GB | GenPPL    1.05]
#                               -> Based on the information provided in the document: 1. **Access Code**: 451646 2. **Locker Number**: 128 3. **Codename**: QUARTZ
#   KiaOmni-Gaussian  B=3400 PASS (3/3 needles)  [  2.9 tok/s | 5.26 GB | GenPPL    1.08]
#                               -> Based on the information provided in the document: 1. **Access Code**: 451646 2. **Locker Number**: 128 3. **Codename**: QUARTZ
#   SnapKV  B=3400           PASS (3/3 needles)  [  3.5 tok/s | 6.34 GB | GenPPL    1.05]
#                               -> Based on the information provided in the document: 1. **Access Code**: 451646 2. **Locker Number**: 128 3. **Codename**: QUARTZ
#
# [multi #2]  prompt = 3955 tokens  |  3 needles @ 20/50/80%
#   GOLD: 651215, 421, HARBOR
# ----------------------------------------------------------------------------------------------------
#   Vanilla (full cache)     PASS (3/3 needles)  [  3.7 tok/s | 6.36 GB | GenPPL    1.07]
#                               -> Based on the information provided in the document: 1. **Access Code**: 651215 2. **Locker Number**: 421 3. **Codename**: HARBOR
#   KiaOmni-Gaussian  B=98   FAIL (2/3 needles)  [  7.1 tok/s | 3.15 GB | GenPPL    1.16]
#                               -> Based on the information provided: 1. The access code is 651215. 2. The locker number is not explicitly mentioned in the given text, so it cannot be determined from th...
#   SnapKV  B=98             FAIL (1/3 needles)  [  6.1 tok/s | 6.32 GB | GenPPL    1.31]
#                               -> Based on the information provided in your request: 1. **Access Code**: 666053 (This was not explicitly stated but derived from the context given in the document.) 2. *...
#   KiaOmni-Gaussian  B=128  FAIL (2/3 needles)  [  6.8 tok/s | 3.15 GB | GenPPL    1.20]
#                               -> Based on the information provided in the document, the three secret values are: 1. Access code: 651215 2. Locker number: Not explicitly mentioned in the text, so it ca...
#   SnapKV  B=128            FAIL (2/3 needles)  [  5.8 tok/s | 6.32 GB | GenPPL    1.16]
#                               -> Based on the information provided in your message, the three secret values are: 1. **Access Code**: 665 2. **Locker Number**: 421 3. **Codename**: HARBOR Please note t...
#   KiaOmni-Gaussian  B=256  PASS (3/3 needles)  [  4.8 tok/s | 3.15 GB | GenPPL    1.02]
#                               -> The three secret values hidden in the document are: 1. Access code: 651215 2. Locker number: 421 3. Codename: HARBOR
#   SnapKV  B=256            FAIL (2/3 needles)  [  6.2 tok/s | 6.32 GB | GenPPL    1.09]
#                               -> Based on the information provided in the document: 1. **Access Code**: The access code is explicitly stated as 652137. 2. **Locker Number**: The spare keys were moved ...
#   KiaOmni-Gaussian  B=512  PASS (3/3 needles)  [  5.2 tok/s | 3.15 GB | GenPPL    1.06]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 651215 2. **Locker Number**: 421 3. **Codename**: HARBOR
#   SnapKV  B=512            FAIL (2/3 needles)  [  6.1 tok/s | 6.32 GB | GenPPL    1.07]
#                               -> Based on the information provided in the document: 1. **Access Code**: The access code is explicitly stated as 6515. 2. **Locker Number**: The spare keys were moved to...
#   KiaOmni-Gaussian  B=1024 PASS (3/3 needles)  [  4.8 tok/s | 3.15 GB | GenPPL    1.05]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 651215 2. **Locker Number**: 421 3. **Codename**: HARBOR
#   SnapKV  B=1024           FAIL (2/3 needles)  [  6.0 tok/s | 6.33 GB | GenPPL    1.08]
#                               -> Based on the information provided in the document: 1. **Access Code**: The access code is explicitly stated to be 6515. 2. **Locker Number**: The spare keys were moved...
#   KiaOmni-Gaussian  B=2048 PASS (3/3 needles)  [  4.2 tok/s | 3.23 GB | GenPPL    1.05]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 651215 2. **Locker Number**: 421 3. **Codename**: HARBOR
#   SnapKV  B=2048           PASS (3/3 needles)  [  5.6 tok/s | 6.34 GB | GenPPL    1.08]
#                               -> Based on the information provided in the document: 1. **Access Code**: The access code is explicitly stated to be 651215. 2. **Locker Number**: The spare keys were mov...
#   KiaOmni-Gaussian  B=3400 PASS (3/3 needles)  [  3.2 tok/s | 5.26 GB | GenPPL    1.06]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 651215 2. **Locker Number**: 421 3. **Codename**: HARBOR
#   SnapKV  B=3400           PASS (3/3 needles)  [  5.0 tok/s | 6.36 GB | GenPPL    1.08]
#                               -> Based on the information provided in the document: 1. **Access Code**: The access code is explicitly stated to be 651215. 2. **Locker Number**: The spare keys were mov...
#
# [multi #3]  prompt = 3948 tokens  |  3 needles @ 20/50/80%
#   GOLD: 888053, 907, HARBOR
# ----------------------------------------------------------------------------------------------------
#   Vanilla (full cache)     PASS (3/3 needles)  [  3.7 tok/s | 6.35 GB | GenPPL    1.07]
#                               -> Based on the information provided in the document: 1. **Access Code**: 888053 2. **Locker Number**: 907 3. **Codename**: HARBOR
#   KiaOmni-Gaussian  B=98   FAIL (1/3 needles)  [  7.3 tok/s | 3.14 GB | GenPPL    1.35]
#                               -> Based on the information provided in the summary: 1. The access code is explicitly stated to be **888053**. 2. There is no additional information given about the locke...
#   SnapKV  B=98             FAIL (1/3 needles)  [  6.2 tok/s | 6.30 GB | GenPPL    1.20]
#                               -> Based on the information provided in your message, the three secret values are: 1. **Access Code**: 8876 (This is derived from the last four digits of the sentence "Fo...
#   KiaOmni-Gaussian  B=128  FAIL (2/3 needles)  [  5.8 tok/s | 3.14 GB | GenPPL    1.17]
#                               -> Based on the information provided in the document, the three secret values are: 1. Access Code: 888053 2. Locker Number: 07 3. Codename: HARBOR These values were deriv...
#   SnapKV  B=128            FAIL (2/3 needles)  [  4.3 tok/s | 6.30 GB | GenPPL    1.14]
#                               -> Based on the information provided in your message, the three secret values are: 1. **Access Code**: 880523 2. **Locker Number**: 907 3. **Codename**: HARBOR
#   KiaOmni-Gaussian  B=256  PASS (3/3 needles)  [  5.0 tok/s | 3.14 GB | GenPPL    1.05]
#                               -> Based on the information provided in the document, the three secret values are: 1. Access code: 888053 2. Locker number: 907 3. Codename: HARBOR
#   SnapKV  B=256            FAIL (2/3 needles)  [  6.1 tok/s | 6.30 GB | GenPPL    1.12]
#                               -> Based on the information provided in your message, the three secret values are: 1. **Access Code**: 8885 2. **Locker Number**: 907 3. **Codename**: HARBOR These values...
#   KiaOmni-Gaussian  B=512  PASS (3/3 needles)  [  5.1 tok/s | 3.14 GB | GenPPL    1.05]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 888053 2. **Locker Number**: 907 3. **Codename**: HARBOR
#   SnapKV  B=512            FAIL (2/3 needles)  [  6.1 tok/s | 6.31 GB | GenPPL    1.20]
#                               -> Based on the information provided in the document: 1. **Access Code**: 88853 2. **Locker Number**: 907 3. **Codename**: HARBOR These values are derived from the explic...
#   KiaOmni-Gaussian  B=1024 PASS (3/3 needles)  [  4.8 tok/s | 3.14 GB | GenPPL    1.04]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 888053 2. **Locker Number**: 907 3. **Codename**: HARBOR
#   SnapKV  B=1024           PASS (3/3 needles)  [  6.1 tok/s | 6.31 GB | GenPPL    1.09]
#                               -> Based on the information provided in the document: 1. **Access Code**: 888053 2. **Locker Number**: 907 3. **Codename**: HARBOR These values are derived from the expli...
#   KiaOmni-Gaussian  B=2048 PASS (3/3 needles)  [  4.3 tok/s | 3.23 GB | GenPPL    1.05]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 888053 2. **Locker Number**: 907 3. **Codename**: HARBOR
#   SnapKV  B=2048           PASS (3/3 needles)  [  3.8 tok/s | 6.33 GB | GenPPL    1.07]
#                               -> Based on the information provided in the document: 1. **Access Code**: 888053 2. **Locker Number**: 907 3. **Codename**: HARBOR
#   KiaOmni-Gaussian  B=3400 PASS (3/3 needles)  [  3.2 tok/s | 5.26 GB | GenPPL    1.06]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 888053 2. **Locker Number**: 907 3. **Codename**: HARBOR
#   SnapKV  B=3400           PASS (3/3 needles)  [  3.5 tok/s | 6.34 GB | GenPPL    1.06]
#                               -> Based on the information provided in the document: 1. **Access Code**: 888053 2. **Locker Number**: 907 3. **Codename**: HARBOR
#
# [multi #4]  prompt = 3954 tokens  |  3 needles @ 20/50/80%
#   GOLD: 231931, 394, QUARTZ
# ----------------------------------------------------------------------------------------------------
#   Vanilla (full cache)     PASS (3/3 needles)  [  3.7 tok/s | 6.36 GB | GenPPL    1.06]
#                               -> Based on the information provided in the document: 1. **Access Code**: 231931 2. **Locker Number**: 394 3. **Codename**: QUARTZ
#   KiaOmni-Gaussian  B=98   FAIL (2/3 needles)  [  6.9 tok/s | 3.15 GB | GenPPL    1.13]
#                               -> Based on the information provided in the document, the three secret values are: 1. Access Code: 231931 2. Locker Number: Not mentioned (the document does not provide a...
#   SnapKV  B=98             FAIL (0/3 needles)  [  6.1 tok/s | 6.31 GB | GenPPL    1.28]
#                               -> Based on the information provided in your message, the three secret values are: 1. **Access Code**: 234567 (This was given as "234567" in your message, but you mention...
#   KiaOmni-Gaussian  B=128  FAIL (2/3 needles)  [  7.0 tok/s | 3.15 GB | GenPPL    1.19]
#                               -> Based on the information provided in the document, the three secret values are: 1. Access Code: 231931 2. Locker Number: Not explicitly mentioned in the text. 3. Coden...
#   SnapKV  B=128            FAIL (2/3 needles)  [  6.1 tok/s | 6.32 GB | GenPPL    1.23]
#                               -> Based on the information provided in your message, the three secret values are: 1. **Access Code**: 234567 (This was given directly in the text as "For reference, the ...
#   KiaOmni-Gaussian  B=256  PASS (3/3 needles)  [  4.7 tok/s | 3.15 GB | GenPPL    1.04]
#                               -> The three secret values hidden in the document are: 1. Access code: 231931 2. Locker number: 394 3. Codename: QUARTZ
#   SnapKV  B=256            FAIL (2/3 needles)  [  6.1 tok/s | 6.32 GB | GenPPL    1.17]
#                               -> Based on the information provided in the document: 1. **Access Code**: 239478 (This was not explicitly stated but derived from "For your records, the access code is 23...
#   KiaOmni-Gaussian  B=512  PASS (3/3 needles)  [  4.9 tok/s | 3.15 GB | GenPPL    1.06]
#                               -> Based on the information provided in the document, the three secret values are: 1. Access code: 231931 2. Locker number: 394 3. Codename: QUARTZ
#   SnapKV  B=512            FAIL (2/3 needles)  [  6.0 tok/s | 6.32 GB | GenPPL    1.08]
#                               -> Based on the information provided in the document: 1. **Access Code**: The access code is explicitly stated to be 23131. 2. **Locker Number**: The spare keys were move...
#   KiaOmni-Gaussian  B=1024 PASS (3/3 needles)  [  4.8 tok/s | 3.15 GB | GenPPL    1.04]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 231931 2. **Locker Number**: 394 3. **Codename**: QUARTZ
#   SnapKV  B=1024           PASS (3/3 needles)  [  4.0 tok/s | 6.33 GB | GenPPL    1.06]
#                               -> Based on the information provided in the document: 1. **Access Code**: 231931 2. **Locker Number**: 394 3. **Codename**: QUARTZ
#   KiaOmni-Gaussian  B=2048 PASS (3/3 needles)  [  4.3 tok/s | 3.23 GB | GenPPL    1.05]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 231931 2. **Locker Number**: 394 3. **Codename**: QUARTZ
#   SnapKV  B=2048           PASS (3/3 needles)  [  3.8 tok/s | 6.34 GB | GenPPL    1.05]
#                               -> Based on the information provided in the document: 1. **Access Code**: 231931 2. **Locker Number**: 394 3. **Codename**: QUARTZ
#   KiaOmni-Gaussian  B=3400 PASS (3/3 needles)  [  3.2 tok/s | 5.26 GB | GenPPL    1.05]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 231931 2. **Locker Number**: 394 3. **Codename**: QUARTZ
#   SnapKV  B=3400           PASS (3/3 needles)  [  3.5 tok/s | 6.36 GB | GenPPL    1.05]
#                               -> Based on the information provided in the document: 1. **Access Code**: 231931 2. **Locker Number**: 394 3. **Codename**: QUARTZ
#
# [multi #5]  prompt = 3949 tokens  |  3 needles @ 20/50/80%
#   GOLD: 163194, 629, HARBOR
# ----------------------------------------------------------------------------------------------------
#   Vanilla (full cache)     PASS (3/3 needles)  [  3.7 tok/s | 6.35 GB | GenPPL    1.06]
#                               -> Based on the information provided in the document: 1. **Access Code**: 163194 2. **Locker Number**: 629 3. **Codename**: HARBOR
#   KiaOmni-Gaussian  B=98   FAIL (1/3 needles)  [  7.1 tok/s | 3.14 GB | GenPPL    1.19]
#                               -> Based on the information provided in the memo: 1. **Access Code**: 163194 2. **Locker Number**: Not mentioned in the given text. 3. **Codename**: Not mentioned in the ...
#   SnapKV  B=98             FAIL (1/3 needles)  [  6.1 tok/s | 6.30 GB | GenPPL    1.40]
#                               -> Based on the information provided in your message, the three secret values are: 1. **Access Code**: 165478 (This was not explicitly stated as the access code in your m...
#   KiaOmni-Gaussian  B=128  FAIL (2/3 needles)  [  6.6 tok/s | 3.14 GB | GenPPL    1.15]
#                               -> Based on the information provided in the document, the three secret values are: 1. Access code: 163194 2. Locker number: Not explicitly mentioned (the document only me...
#   SnapKV  B=128            FAIL (1/3 needles)  [  6.1 tok/s | 6.30 GB | GenPPL    1.40]
#                               -> Based on the information provided in your message, the three secret values are: 1. **Access Code**: 161994 (This was given as "161994" in the text, but it's commonly r...
#   KiaOmni-Gaussian  B=256  PASS (3/3 needles)  [  5.1 tok/s | 3.14 GB | GenPPL    1.04]
#                               -> Based on the information provided in the document, the three secret values are: 1. Access code: 163194 2. Locker number: 629 3. Codename: HARBOR
#   SnapKV  B=256            FAIL (2/3 needles)  [  6.1 tok/s | 6.31 GB | GenPPL    1.15]
#                               -> Based on the information provided in the document: 1. **Access Code**: 16394 (This is derived from the last four digits of the sentence "For the record, the access cod...
#   KiaOmni-Gaussian  B=512  PASS (3/3 needles)  [  5.0 tok/s | 3.14 GB | GenPPL    1.05]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 163194 2. **Locker Number**: 629 3. **Codename**: HARBOR
#   SnapKV  B=512            FAIL (2/3 needles)  [  6.1 tok/s | 6.31 GB | GenPPL    1.12]
#                               -> Based on the information provided in the document: 1. **Access Code**: 16394 2. **Locker Number**: 629 3. **Codename**: HARBOR These values are derived from the explic...
#   KiaOmni-Gaussian  B=1024 PASS (3/3 needles)  [  4.9 tok/s | 3.14 GB | GenPPL    1.04]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 163194 2. **Locker Number**: 629 3. **Codename**: HARBOR
#   SnapKV  B=1024           FAIL (2/3 needles)  [  6.0 tok/s | 6.32 GB | GenPPL    1.08]
#                               -> Based on the information provided in the document: 1. **Access Code**: 16394 2. **Locker Number**: 629 3. **Codename**: HARBOR These values are derived directly from t...
#   KiaOmni-Gaussian  B=2048 PASS (3/3 needles)  [  4.3 tok/s | 3.23 GB | GenPPL    1.05]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 163194 2. **Locker Number**: 629 3. **Codename**: HARBOR
#   SnapKV  B=2048           PASS (3/3 needles)  [  3.8 tok/s | 6.33 GB | GenPPL    1.06]
#                               -> Based on the information provided in the document: 1. **Access Code**: 163194 2. **Locker Number**: 629 3. **Codename**: HARBOR
#   KiaOmni-Gaussian  B=3400 PASS (3/3 needles)  [  3.2 tok/s | 5.26 GB | GenPPL    1.06]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 163194 2. **Locker Number**: 629 3. **Codename**: HARBOR
#   SnapKV  B=3400           PASS (3/3 needles)  [  3.5 tok/s | 6.35 GB | GenPPL    1.06]
#                               -> Based on the information provided in the document: 1. **Access Code**: 163194 2. **Locker Number**: 629 3. **Codename**: HARBOR
#
# [multi #6]  prompt = 3957 tokens  |  3 needles @ 20/50/80%
#   GOLD: 580514, 446, FALCON
# ----------------------------------------------------------------------------------------------------
#   Vanilla (full cache)     PASS (3/3 needles)  [  5.3 tok/s | 6.37 GB | GenPPL    1.08]
#                               -> Based on the information provided in the document: 1. **Access Code**: The access code is explicitly stated to be 580514. 2. **Locker Number**: The spare keys were mov...
#   KiaOmni-Gaussian  B=98   FAIL (1/3 needles)  [  7.1 tok/s | 3.15 GB | GenPPL    1.18]
#                               -> Based on the information provided in the memo: 1. **Access Code**: 580514 2. **Locker Number**: Not explicitly mentioned in the given text. 3. **Codename**: liaisonALC...
#   SnapKV  B=98             FAIL (1/3 needles)  [  6.1 tok/s | 6.32 GB | GenPPL    1.33]
#                               -> Based on the information provided in your request: 1. **Access Code**: The access code is explicitly stated as 581-234. 2. **Locker Number**: The locker number is ment...
#   KiaOmni-Gaussian  B=128  FAIL (2/3 needles)  [  6.6 tok/s | 3.15 GB | GenPPL    1.17]
#                               -> Based on the information provided in the document, the three secret values are: 1. Access code: 580514 2. Locker number: Not explicitly mentioned (the document only me...
#   SnapKV  B=128            FAIL (2/3 needles)  [  6.1 tok/s | 6.32 GB | GenPPL    1.19]
#                               -> Based on the information provided in your message, the three secret values are: 1. **Access Code**: 550142 2. **Locker Number**: 446 3. **Codename**: FALCON These valu...
#   KiaOmni-Gaussian  B=256  PASS (3/3 needles)  [  5.1 tok/s | 3.15 GB | GenPPL    1.04]
#                               -> Based on the information provided in the document, the three secret values are: 1. Access code: 580514 2. Locker number: 446 3. Codename: FALCON
#   SnapKV  B=256            FAIL (2/3 needles)  [  6.1 tok/s | 6.32 GB | GenPPL    1.17]
#                               -> Based on the information provided in the document: 1. **Access Code**: The access code is explicitly stated as 581406. 2. **Locker Number**: The spare keys were moved ...
#   KiaOmni-Gaussian  B=512  PASS (3/3 needles)  [  5.0 tok/s | 3.15 GB | GenPPL    1.04]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 580514 2. **Locker Number**: 446 3. **Codename**: FALCON
#   SnapKV  B=512            PASS (3/3 needles)  [  6.0 tok/s | 6.33 GB | GenPPL    1.16]
#                               -> Based on the information provided in the document: 1. **Access Code**: The access code is explicitly stated to be 580514. 2. **Locker Number**: The spare keys were mov...
#   KiaOmni-Gaussian  B=1024 PASS (3/3 needles)  [  4.8 tok/s | 3.15 GB | GenPPL    1.04]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 580514 2. **Locker Number**: 446 3. **Codename**: FALCON
#   SnapKV  B=1024           FAIL (2/3 needles)  [  6.0 tok/s | 6.33 GB | GenPPL    1.07]
#                               -> Based on the information provided in the document: 1. **Access Code**: The access code is explicitly stated to be 58014. 2. **Locker Number**: The spare keys were move...
#   KiaOmni-Gaussian  B=2048 PASS (3/3 needles)  [  4.2 tok/s | 3.23 GB | GenPPL    1.05]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 580514 2. **Locker Number**: 446 3. **Codename**: FALCON
#   SnapKV  B=2048           PASS (3/3 needles)  [  5.6 tok/s | 6.34 GB | GenPPL    1.08]
#                               -> Based on the information provided in the document: 1. **Access Code**: The access code is explicitly stated to be 580514. 2. **Locker Number**: The spare keys were mov...
#   KiaOmni-Gaussian  B=3400 PASS (3/3 needles)  [  3.2 tok/s | 5.26 GB | GenPPL    1.07]
#                               -> Based on the information provided in the document, the three secret values are: 1. **Access Code**: 580514 2. **Locker Number**: 446 3. **Codename**: FALCON
#   SnapKV  B=3400           PASS (3/3 needles)  [  5.0 tok/s | 6.36 GB | GenPPL    1.08]
#                               -> Based on the information provided in the document: 1. **Access Code**: The access code is explicitly stated to be 580514. 2. **Locker Number**: The spare keys were mov...
#
# [multi #7]  prompt = 3952 tokens  |  3 needles @ 20/50/80%
#   GOLD: 977419, 525, QUARTZ
# ----------------------------------------------------------------------------------------------------
#   Vanilla (full cache)     PASS (3/3 needles)  [  3.7 tok/s | 6.36 GB | GenPPL    1.07]
#                               -> Based on the information provided in the document: 1. **Access Code**: 977419 2. **Locker Number**: 525 3. **Codename**: QUARTZ
#   KiaOmni-Gaussian  B=98   FAIL (2/3 needles)  [  7.2 tok/s | 3.15 GB | GenPPL    1.33]
#                               -> Based on the information provided in the archive department's records: 1. **Access Code**: The access code mentioned is 977419. 2. **Codename**: The codename for the l...
#   SnapKV  B=98             FAIL (0/3 needles)  [  6.2 tok/s | 6.31 GB | GenPPL    1.33]
# ...
#   SnapKV  B=512            100.0% facts (8/8 key facts)  [  6.1 tok/s | 6.36 GB | GenPPL    1.11]
#     In the latest quarterly review of Altavera Systems, total revenue reached $12.5 million, with a cash runway of 16 months. Headcount stood at 523 employees following the Riga office expansion. Monthly customer churn was 6.1%, and the net promoter score (NPS) was 48. The defect rate improved to 3.9 per thousand units, and the next product launch is scheduled for March.
#   KiaOmni-Gaussian  B=1024 100.0% facts (8/8 key facts)  [  8.1 tok/s | 3.15 GB | GenPPL    1.19]
#     Altavera Systems reported a total revenue of $12.5 million for the quarter, with a cash runway of 16 months. The company's headcount reached 523 employees following an expansion in the Riga office. Monthly customer churn was 6.1%, while the net promoter score (NPS) stood at 48. The defect rate improved to 3.9 per thousand units, and the next product launch is scheduled for March. The northern facility confirmed a backlog of paperwork from the previous quarter, while the logistics team noted the relocation of two storage containers. Stable energy consumption throughout the week was approved by various departments, and general satisfaction with the new canteen layout was confirmed across multiple reviews.
#   SnapKV  B=1024           100.0% facts (8/8 key facts)  [  5.9 tok/s | 6.37 GB | GenPPL    1.10]
#     In the latest quarterly review of Altavera Systems, total revenue reached $12.5 million, with a cash runway of 16 months. Headcount stood at 523 employees following the Riga office expansion. Monthly customer churn was 6.1%, and the net promoter score (NPS) was 48. The defect rate improved to 3.9 per thousand units, and the next product launch is scheduled for March.
#   KiaOmni-Gaussian  B=2048 100.0% facts (8/8 key facts)  [  7.7 tok/s | 3.23 GB | GenPPL    1.18]
#     Altavera Systems reported a total revenue of $12.5 million for the quarter, with a cash runway of 16 months. The company's headcount reached 523 employees following an expansion in Riga. Monthly customer churn was 6.1%, while the net promoter score (NPS) stood at 48. The defect rate improved to 3.9 per thousand units, and the next product launch is scheduled for March. The northern facility in the northern region confirmed a backlog of paperwork from the previous quarter, and the logistics team approved the relocation of two storage containers. Monthly churn was 6.1%, and the net promoter score (NPS) was 48. The defect rate was 3.9 per thousand units, and the next product launch is set for March.
#   SnapKV  B=2048           100.0% facts (8/8 key facts)  [  6.1 tok/s | 6.38 GB | GenPPL    1.20]
#     In the latest quarterly review of Altavera Systems, total revenue reached $12.5 million, with a cash runway of 16 months. The company's headcount stood at 523 employees following the Riga office expansion. Monthly customer churn was 6.1%, and the net promoter score (NPS) was 48. The defect rate improved to 3.9 per thousand units, and the next product launch is scheduled for March. These metrics reflect ongoing operational improvements and steady growth in various departments including finance, people, customers, and operations.
#   KiaOmni-Gaussian  B=3400 100.0% facts (8/8 key facts)  [  5.2 tok/s | 5.26 GB | GenPPL    1.18]
#     Altavera Systems reported a total revenue of $12.5 million for the quarter, with a cash runway of 16 months. The company's headcount reached 523 employees following an expansion in Riga. Monthly customer churn was 6.1%, while the net promoter score (NPS) stood at 48. The defect rate improved to 3.9 per thousand units, and the next product launch is scheduled for March. The northern facility in the northern city confirmed a backlog of paperwork from the previous quarter, and the defect rate improvement was noted across operations.
#   SnapKV  B=3400           100.0% facts (8/8 key facts)  [  5.6 tok/s | 6.40 GB | GenPPL    1.24]
#     In the latest quarterly review of Altavera Systems, total revenue reached $12.5 million, with a cash runway of 16 months. The company expanded its Riga office, increasing headcount to 523 employees. Monthly customer churn was 6.1%, and the net promoter score (NPS) stood at 48. The defect rate improved to 3.9 per thousand units, and the next product launch is scheduled for March. The company relocated two storage containers and replaced worn signage near gate three. Operations focused on improving energy consumption, humidity levels, and addressing paperwork backlogs, with a defect rate improvement to 3.9 per thousand units.
#
# [summary #3]  prompt = 3961 tokens  |  Norwind Logistics, 8 planted facts
#   GOLD: revenue=29.1 million; headcount=496; churn=9.4%; nps=50; runway=25 months; city=Valencia; defects=5.4 per thousand units; launch=November
# ----------------------------------------------------------------------------------------------------
#   Vanilla (full cache)      100.0% facts (8/8 key facts)  [  6.2 tok/s | 6.38 GB | GenPPL    1.19]
#     In the latest quarterly review of Norwind Logistics, total revenue reached $29.1 million, with a cash runway of 25 months. Headcount stood at 496 employees following the Valencia office expansion. Monthly customer churn was 9.4%, while the net promoter score (NPS) was 50. The defect rate improved to 5.4 per thousand units, and the next product launch is scheduled for November. The company successfully implemented an updated rotation plan for night shifts and addressed minor adjustments to the ventilation schedule, with stable energy consumption maintained throughout the week. Worn signage near gate three was replaced, and general satisfaction with the new canteen layout was noted. Operations continued to improve, with a gradual rise in afternoon foot traffic observed.
#   KiaOmni-Gaussian  B=98     0.0% facts (0/8 key facts)  [  8.7 tok/s | 3.15 GB | GenPPL    1.36]
#     In the latest quarterly review of Norwind Logistics, the pilot program confirmed that the updated rotation revenue for the quarter was $1.2 million, marking a significant increase from the previous period. The company added 10 new employees, bringing the total headcount to 55, while customer churn remained at 3%, indicating stable customer retention. The Net Promoter Score (NPS) improved to +45, reflecting higher customer satisfaction. Norwind Logistics has a runway of 18 months based on current cash flow, providing ample financial stability. The company expanded its operations to its fifth city, Denver, in March, and plans to continue expanding to additional markets. Additionally, the defect rate for their logistics services decreased to 1.5%, down from 2% in the previous quarter, showcasing improvements in service quality.
#   SnapKV  B=98              12.5% facts (1/8 key facts)  [  7.3 tok/s | 6.33 GB | GenPPL    1.43]
#     In the latest quarterly review of Norwind Logistics (hypothetical company name), the revenue stood at a significant level, though the exact figure was not specified. The headcount increased to 1,200 following the expansion into the city of Norwind, with the addition of 300 new positions. The defect rate improved to 1.5%, indicating enhanced quality control processes. The monthly churn rate was reported at 1.2%, while the Net Promoter Score (NPS) reached 70, reflecting customer satisfaction. The company's financial runway extended to 24 months, providing ample financial stability. Additionally, the next product launch is scheduled for November, marking the start of the new fiscal year.
#   KiaOmni-Gaussian  B=128   37.5% facts (3/8 key facts)  [  7.6 tok/s | 3.15 GB | GenPPL    1.25]
#     In the latest quarterly review of Norwind Logistics, the company reported total revenue of $29.1 million. The Valencia office expansion is nearing completion, with new signage installed near Gate Three. The pilot program confirmed an updated rotation plan for night shifts. While specific figures for churn, Net Promoter Score (NPS), runway, defect rate, and launch month were not provided, these metrics are likely being closely monitored to ensure operational efficiency and customer satisfaction. The headcount stood at 496 employees as of the end of the quarter.
#   SnapKV  B=128             37.5% facts (3/8 key facts)  [  5.9 tok/s | 6.33 GB | GenPPL    1.30]
#     In the latest quarterly review of Norwind Logistics, total revenue reached $3.5 million, with a cash runway of 9 months. Headcount increased to 120 following the expansion into Valencia, Spain. Customer churn stood at 5%, while the net promoter score (NPS) was 50. The defect rate improved to 0.4%, and the company is set to launch its next product in November.
#   KiaOmni-Gaussian  B=256   87.5% facts (7/8 key facts)  [  8.1 tok/s | 3.15 GB | GenPPL    1.16]
#     Norwind Logistics reported a total revenue of $29.1 million for the quarter, with a cash runway extending to 25 months. The company's headcount increased to 496 employees following the expansion of its Valencia office. Monthly customer churn stood at 9.4%, while the net promoter score (NPS) reached 50. A quarterly audit was conducted, and minor adjustments were made to the ventilation schedule during the pilot program. Night shift rotations were updated, and a product launch is scheduled for November. Additionally, worn signage near gate three will be replaced, and a regional backlog of paperwork from the previous quarter was addressed.
#   SnapKV  B=256             75.0% facts (6/8 key facts)  [  6.6 tok/s | 6.33 GB | GenPPL    1.20]
#     In the latest quarterly review of Norwind Logistics, total revenue reached $29.1 million (including $29.1 million from the previous quarter and an additional $1 million from the current quarter), with a cash runway of 29 months. Headcount increased to 496 employees following the Valencia office expansion. Monthly customer churn was 9.4%, and the net promoter score (NPS) stood at 48. The defect rate improved to 5.4 per thousand units. Norwind Logistics plans its next product launch for November.
#   KiaOmni-Gaussian  B=512  100.0% facts (8/8 key facts)  [  8.1 tok/s | 3.15 GB | GenPPL    1.17]
#     Norwind Logistics reported a total revenue of $29.1 million for the quarter, with a cash runway of 25 months. The company's headcount increased to 496 employees following the expansion of the Valencia office. Monthly customer churn was 9.4%, while the net promoter score (NPS) stood at 50. The defect rate improved to 5.4 per thousand units, and the next product launch is scheduled for November. Night shift energy consumption remained stable, and a pilot program confirmed an updated rotation plan. The logistics team noted general satisfaction with the new canteen layout, which was also confirmed by the northern facility.
#   SnapKV  B=512            100.0% facts (8/8 key facts)  [  6.0 tok/s | 6.33 GB | GenPPL    1.16]
#     In the latest quarterly review of Norwind Logistics, total revenue reached $29.1 million, with a cash runway of 25 months. Headcount stood at 496 employees following the expansion in Valencia. Monthly customer churn was 9.4%, while the net promoter score (NPS) was 50. The defect rate improved to 5.4 per thousand units. The company plans its next product launch for November.
#   KiaOmni-Gaussian  B=1024 100.0% facts (8/8 key facts)  [  7.9 tok/s | 3.15 GB | GenPPL    1.21]
#     In the latest quarterly review of Norwind Logistics, total revenue reached $29.1 million, with a cash runway of 25 months. Headcount increased to 496 employees following the Valencia office expansion. Monthly customer churn stood at 9.4%, while the net promoter score (NPS) was 50. Night shift rotations were updated, and the defect rate improved to 5.4 per thousand units. The next product launch is scheduled for November. Notable projects included the replacement of worn signage near Gate Three, minor adjustments to the ventilation schedule, and the relocation of two storage containers. The company also addressed a backlog of paperwork and evaluated stable energy consumption throughout the week.
#   SnapKV  B=1024           100.0% facts (8/8 key facts)  [  7.0 tok/s | 6.34 GB | GenPPL    1.27]
#     In the latest quarterly review of Norwind Logistics, total revenue reached $29.1 million, with a cash runway of 25 months. Headcount stood at 496 employees following the expansion in Valencia. Monthly customer churn was 9.4%, while the net promoter score (NPS) was 50. The defect rate improved to 5.4 per thousand units, and the next product launch is scheduled for November. The company evaluated various operations, including a pilot program for night shifts, maintenance of ventilation schedules, and the replacement of worn signage near gate three. Monthly churn and NPS scores were closely monitored, alongside the defect rate and upcoming product launch timeline.
#   KiaOmni-Gaussian  B=2048 100.0% facts (8/8 key facts)  [  6.8 tok/s | 3.23 GB | GenPPL    1.18]
#     In the latest quarterly review of Norwind Logistics, total revenue reached $29.1 million, with a cash runway of 25 months. Headcount increased to 496 employees following the Valencia office expansion. Monthly customer churn was 9.4%, while the net promoter score (NPS) stood at 50. The defect rate improved to 5.4 per thousand units, and the next product launch is scheduled for November. Night shift rotations were updated, and the company evaluated stable energy consumption throughout the week. General satisfaction with the new canteen layout was noted across various departments and surveys.
#   SnapKV  B=2048           100.0% facts (8/8 key facts)  [  6.2 tok/s | 6.35 GB | GenPPL    1.20]
#     In the latest quarterly review of Norwind Logistics, total revenue reached $29.1 million, with a cash runway of 25 months. Headcount stood at 496 employees following the Valencia office expansion. Monthly customer churn was 9.4%, while the net promoter score (NPS) was 50. The defect rate improved to 5.4 per thousand units, and the next product launch is scheduled for November. The review covered various operations including maintenance, logistics, and customer satisfaction, with notable projects such as the replacement of worn signage near gate three and the relocation of two storage containers.
#   KiaOmni-Gaussian  B=3400 100.0% facts (8/8 key facts)  [  5.3 tok/s | 5.26 GB | GenPPL    1.21]
#     In the latest quarterly review of Norwind Logistics, total revenue reached $29.1 million, with a cash runway of 25 months. Headcount stood at 496 employees following the expansion in Valencia. Monthly customer churn was 9.4%, while the net promoter score (NPS) was 50. The defect rate improved to 5.4 per thousand units, and the next product launch is scheduled for November. Night shift rotations were updated, and the company evaluated stable energy consumption throughout the week. The relocation of two storage containers was confirmed, and general satisfaction with the new canteen layout was reported.
#   SnapKV  B=3400           100.0% facts (8/8 key facts)  [  5.6 tok/s | 6.37 GB | GenPPL    1.24]
#     In the latest quarterly review of Norwind Logistics, total revenue reached $29.1 million, with a cash runway of 25 months. Headcount stood at 496 employees following the Valencia office expansion. Monthly customer churn was 9.4%, while the net promoter score (NPS) was 50. The defect rate improved to 5.4 per thousand units, and the next product launch is scheduled for November. The company successfully implemented an updated rotation plan for night shifts and addressed minor adjustments to the ventilation schedule. The defect rate improvement and the upcoming product launch highlight the company's progress and focus on operational efficiency and customer satisfaction.
#
# Done. 495 generations in 84.7 min.

# %%
# --- Final tables, chart, CSV -----------------------------------------------------
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(results)
df["score_pct"] = df["score"] * 100
df["config"] = df.apply(
    lambda r: "Vanilla (full)" if r["method"] == "Vanilla" else f"{r['method']} B={int(r['budget'])}", axis=1)

row_order = (["Vanilla (full)"]
             + [f"{m} B={b}" for b in BUDGETS for m in ("KiaOmni-Gaussian", "SnapKV")])

print("ACCURACY / COVERAGE (%) -- single, multi, reason = accuracy; summary = key-fact coverage")
acc = (df.pivot_table(index="config", columns="task", values="score_pct", aggfunc="mean")
         .reindex(row_order)[["single", "multi", "reason", "summary"]].round(1))
acc["needle_mean"] = acc[["single", "multi", "reason"]].mean(axis=1).round(1)
print(acc.to_string(), "\n")

print("EFFICIENCY (means over all generations)")
eff_cols = ["tps", "vram"] + (["ppl"] if VERBOSE else [])
eff = df.groupby("config")[eff_cols].mean().reindex(row_order).round(2)
eff.columns = ["tokens/sec", "peak VRAM (GB)"] + (["Gen-PPL"] if VERBOSE else [])
print(eff.to_string(), "\n")

# --- chart: mean retrieval+reasoning accuracy per budget --------------------------
fig, ax = plt.subplots(figsize=(9, 4.5))
needle = df[df["task"].isin(["single", "multi", "reason"])]
van = needle[needle["method"] == "Vanilla"]["score_pct"].mean()
width = 0.36
xs = range(len(BUDGETS))
for off, (m, color) in enumerate([("KiaOmni-Gaussian", "#3fa7d6"), ("SnapKV", "#e05c5c")]):
    ys = [needle[(needle["method"] == m) & (needle["budget"] == b)]["score_pct"].mean() for b in BUDGETS]
    ax.bar([x + (off - 0.5) * width for x in xs], ys, width, label=m, color=color)
    for x, y in zip(xs, ys):
        ax.text(x + (off - 0.5) * width, y + 1, f"{y:.0f}", ha="center", fontsize=9)
ax.axhline(van, ls="--", c="gray", label=f"Vanilla ({van:.0f}%)")
ax.set_xticks(list(xs)); ax.set_xticklabels([f"B={b}" for b in BUDGETS])
ax.set_ylabel("Mean accuracy % (single + multi + reason)")
ax.set_title(f"{MODEL_NAME} (NF4, ~{CONTEXT_TOKENS} tok context) -- exact-budget comparison")
ax.set_ylim(0, 105); ax.legend()
plt.tight_layout(); plt.show()

df.drop(columns=["score_pct"]).to_csv("kiaomni_vs_snapkv_results.csv", index=False)
print("Full per-generation log (including all answer texts) saved to kiaomni_vs_snapkv_results.csv")
# Out:
# ACCURACY / COVERAGE (%) -- single, multi, reason = accuracy; summary = key-fact coverage
# task                     single  multi  reason  summary  needle_mean
# config
# Vanilla (full)            100.0  100.0     0.0    100.0         66.7
# KiaOmni-Gaussian B=98     100.0    0.0     0.0      4.2         33.3
# SnapKV B=98                 0.0    0.0     0.0     12.5          0.0
# KiaOmni-Gaussian B=128    100.0    0.0     0.0     29.2         33.3
# SnapKV B=128                0.0    0.0     0.0     29.2          0.0
# KiaOmni-Gaussian B=256    100.0  100.0    20.0     91.7         73.3
# SnapKV B=256               40.0    0.0     0.0     83.3         13.3
# KiaOmni-Gaussian B=512    100.0  100.0    40.0    100.0         80.0
# SnapKV B=512               80.0   20.0     0.0    100.0         33.3
# KiaOmni-Gaussian B=1024   100.0  100.0    10.0    100.0         70.0
# SnapKV B=1024              90.0   40.0     0.0    100.0         43.3
# KiaOmni-Gaussian B=2048   100.0  100.0    10.0    100.0         70.0
# SnapKV B=2048             100.0   90.0     0.0    100.0         63.3
# KiaOmni-Gaussian B=3400   100.0  100.0    10.0    100.0         70.0
# SnapKV B=3400             100.0  100.0     0.0    100.0         66.7
#
# EFFICIENCY (means over all generations)
#                          tokens/sec  peak VRAM (GB)  Gen-PPL
# config
# Vanilla (full)                 2.22            6.40     1.05
# KiaOmni-Gaussian B=98          3.39            3.15     1.11
# SnapKV B=98                    2.93            6.35     1.43
# KiaOmni-Gaussian B=128         3.19            3.15     1.12
# SnapKV B=128                   2.78            6.35     1.27
# KiaOmni-Gaussian B=256         2.92            3.15     1.04
# SnapKV B=256                   2.90            6.35     1.21
# KiaOmni-Gaussian B=512         2.89            3.15     1.04
# SnapKV B=512                   2.89            6.36     1.15
# KiaOmni-Gaussian B=1024        2.77            3.15     1.04
# SnapKV B=1024                  2.65            6.36     1.11
# KiaOmni-Gaussian B=2048        2.43            3.23     1.05
# SnapKV B=2048                  2.42            6.37     1.07
# KiaOmni-Gaussian B=3400        1.76            5.26     1.05
# SnapKV B=3400                  2.16            6.39     1.06
# Full per-generation log (including all answer texts) saved to kiaomni_vs_snapkv_results.csv

# %% [markdown]
# ## Notes and caveats
#
# - **Small N by design.** This is a live, fully-printed demo (10/10/10 questions + 3 documents), not a
#   paper-scale evaluation — confidence intervals are wide. The paper-scale numbers (61,681 LLM-judged
#   samples) live in the [KiaOmni repo](https://github.com/Aliw02/kiaomni).
# - **SnapKV is the NVIDIA `kvpress` reference implementation**, run at its published defaults
#   (`window_size=64`, `kernel_size=5`), GQA-correct, with question-aware compression (the question is part
#   of the prompt at prefill, which is SnapKV's intended strongest setting).
# - **Budget matching is exact per sample**: both methods retain the same number of KV positions.
#   Vanilla keeps the full cache and is the soft upper bound.
# - **Generation-PPL** (VERBOSE mode) is the perplexity of the model over its *own* greedy tokens while
#   answering from a compressed cache. It measures fluency/confidence under eviction and is comparable
#   across the three variants — it is **not** WikiText perplexity.
# - Greedy decoding, fp16 compute, NF4 weights, SDPA backend. Tasks are synthetic and seeded —
#   rerunning reproduces the exact same prompts.
